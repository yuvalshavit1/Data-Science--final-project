# %%
#DATA CLEANING
#Handling missing data - handling double rows, handling titles whose value is missing
#adding values for missing matches according to the most common value - only if the number of missing cells in each category is less than 20% 
#turning age and duration into int variables

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 600
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('merged-csv-files.csv', header=0, sep=',',index_col=[0])

# %%
df.shape
# Out:
# (5202, 14)

# %%
df.head()
# Out:
#                                        Title    Year Duration  MostLiked  \
# 0                           The Adam Project  2022.0   1h 46m        0.0
# 1                               Interstellar  2014.0   2h 49m        1.0
# 2                                 Red Notice  2021.0   1h 58m        0.0
# 3                                  Abduction  2011.0   1h 45m        0.0
# 4  13 Hours: The Secret Soldiers of Benghazi  2016.0   2h 25m        0.0
#
#                                          Description  \
# 0  After accidentally crash-landing in 2022, time...
# 1  With humanity teetering on the brink of extinc...
# 2  An FBI profiler pursuing the world's most want...
# 3  When a teen comes across his own childhood pho...
# 4  Members of an elite security team battle to sa...
#
#                                                 Cast  \
# 0  ['Ryan Reynolds,', 'Mark Ruffalo,', 'Jennifer ...
# 1  ['Matthew McConaughey,', 'Anne Hathaway,', 'Je...
# 2  ['Dwayne Johnson,', 'Ryan Reynolds,', 'Gal Gad...
# 3  ['Taylor Lautner,', 'Lily Collins,', 'Alfred M...
# 4  ['John Krasinski,', 'James Badge Dale,', 'Max ...
#
#                                                Genre  \
# 0  ['Sci-Fi Movies,', 'Family Movies,', 'Action &...
# 1  ['Sci-Fi Movies,', 'Action & Adventure,', 'Dra...
# 2  ['Action & Adventure,', 'Comedies,', 'Crime Mo...
# 3               ['Mysteries,', 'Action & Adventure']
# 4  ['Military Movies,', 'Movies Based on Real Lif...
#
#                                   About                     Director  \
# 0  ['Witty,', 'Feel-Good,', 'Exciting']               ['Shawn Levy']
# 1         ['Mind-Bending,', 'Cerebral']        ['Christopher Nolan']
# 2           ['Irreverent,', 'Exciting']  ['Rawson Marshall Thurber']
# 3          ['Suspenseful,', 'Exciting']           ['John Singleton']
# 4               ['Gritty,', 'Exciting']              ['Michael Bay']
#
#                                             FullCast  \
# 0  ['Ryan Reynolds,', 'Mark Ruffalo,', 'Jennifer ...
# 1  ['Matthew McConaughey,', 'Anne Hathaway,', 'Je...
# 2  ['Dwayne Johnson,', 'Ryan Reynolds,', 'Gal Gad...
# 3  ['Taylor Lautner,', 'Lily Collins,', 'Alfred M...
# 4  ['John Krasinski,', 'James Badge Dale,', 'Max ...
#
#                                               Writer  \
# 0  ['Jonathan Tropper,', 'T.S. Nowlin,', 'Jennife...
# 1           ['Jonathan Nolan,', 'Christopher Nolan']
# 2                        ['Rawson Marshall Thurber']
# 3                              ['Shawn Christensen']
# 4                                    ['Chuck Hogan']
#
#                                            GenreFull  \
# 0  ['Sci-Fi Movies,', 'Family Movies,', 'Action &...
# 1  ['Sci-Fi Movies,', 'Action & Adventure,', 'Dra...
# 2  ['Action & Adventure,', 'Comedies,', 'Crime Mo...
# 3               ['Mysteries,', 'Action & Adventure']
# 4  ['Military Movies,', 'Movies Based on Real Lif...
#
#                               AboutFull  Age
# 0  ['Witty,', 'Feel-Good,', 'Exciting']  13+
# 1         ['Mind-Bending,', 'Cerebral']  13+
# 2           ['Irreverent,', 'Exciting']  13+
# 3          ['Suspenseful,', 'Exciting']  13+
# 4               ['Gritty,', 'Exciting']  16+

# %%
#check how many NULL in Title column
df.Title.isnull().sum()
# Out:
# 63

# %%
#delete the rows with NULL value in Title
df.dropna(subset=['Title'],inplace=True)

# %%
#check how many NULL in Title column
df.Title.isnull().sum()
# Out:
# 0

# %%
#delete the column Writer
df.drop('Writer', inplace=True, axis=1)

# %%
#delete the column Cast
df.drop('Cast', inplace=True, axis=1)

# %%
#delete the column About
df.drop('About', inplace=True, axis=1)

# %%
#delete the column Genre
df.drop('Genre', inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5139 entries, 0 to 302
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        5139 non-null   object
#  1   Year         5139 non-null   float64
#  2   Duration     5139 non-null   object
#  3   MostLiked    5139 non-null   float64
#  4   Description  5112 non-null   object
#  5   Director     4901 non-null   object
#  6   FullCast     4808 non-null   object
#  7   GenreFull    5113 non-null   object
#  8   AboutFull    4606 non-null   object
#  9   Age          5139 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 441.6+ KB

# %%
#check how many rows and columns left after delete Titles with NULL value
df.shape
# Out:
# (5139, 10)

# %%
#check if there is duplicated rows
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298     True
# 299     True
# 300    False
# 301    False
# 302    False
# Length: 5139, dtype: bool

# %%
#show the duplicated rows by the same *title*
df[df.duplicated(['Title','Year'])]
# Out:
#                                     Title    Year Duration  MostLiked  \
# 482                              Wild Dog  2020.0    2h 6m        0.0
# 491                              Wild Dog  2020.0    2h 6m        0.0
# 502                              Wild Dog  2020.0    2h 6m        0.0
# 6                       Princess Mononoke  1997.0   2h 14m        1.0
# 20     The Witcher: Nightmare of the Wolf  2021.0   1h 23m        0.0
# ..                                    ...     ...      ...        ...
# 296                            In Paradox  2019.0   1h 33m        0.0
# 297                       Krishna Cottage  2004.0    2h 3m        0.0
# 298  Albert Pinto Ko Gussa Kyun Aata Hai?  2019.0   1h 25m        0.0
# 299                    Muqaddar ka Faisla  1987.0   2h 51m        0.0
# 301                        Seven (Telugu)  2019.0   1h 55m        0.0
#
#                                            Description             Director  \
# 482  A brash but brilliant Indian intelligence agen...  ['Ahishor Solomon']
# 491  A brash but brilliant Indian intelligence agen...  ['Ahishor Solomon']
# 502  A brash but brilliant Indian intelligence agen...  ['Ahishor Solomon']
# 6    A prince infected with a lethal curse sets off...   ['Hayao Miyazaki']
# 20   From the creative minds behind the blockbuster...     ['Han Kwang Il']
# ..                                                 ...                  ...
# 296  On the run from assailants, a man desperately ...   ['Hamad AlSarraf']
# 297  True love is put to the test when another woma...    ['Santram Varma']
# 298  As the police investigate his disappearance, a...  ['Soumitra Ranade']
# 299  God-fearing Pandit Krishna Kant loses everythi...    ['Prakash Mehra']
# 301  Multiple women report their husbands as missin...                  Nan
#
#                                               FullCast  \
# 482  ['Nagarjuna Akkineni,', 'Dia Mirza,', 'Saiyami...
# 491  ['Nagarjuna Akkineni,', 'Dia Mirza,', 'Saiyami...
# 502  ['Nagarjuna Akkineni,', 'Dia Mirza,', 'Saiyami...
# 6    ['Yoji Matsuda,', 'Yuriko Ishida,', 'Yuko Tana...
# 20   ['Theo James,', 'Mary McDonnell,', 'Lara Pulve...
# ..                                                 ...
# 296  ['Faisal Al Omairi,', 'Jafra Younes,', 'Samr I...
# 297  ['Sohail Khan,', 'Isha Koppikar,', 'Natassha,'...
# 298  ['Nandita Das,', 'Manav Kaul,', 'Saurabh Shukl...
# 299  ['Raaj Kumar,', 'Rakhee Gulzar,', 'Raj Babbar,...
# 301                                                Nan
#
#                                              GenreFull  \
# 482  ['Indian,', 'Kannada Movies & TV,', 'Action & ...
# 491  ['Indian,', 'Tamil-Language Movies,', 'Action ...
# 502  ['Indian,', 'Malayalam-Language Movies,', 'Act...
# 6    ['Japanese,', 'Family Movies,', 'Fantasy Anime...
# 20   ['TV Shows Based on Books,', 'Movies Based on ...
# ..                                                 ...
# 296  ['Kuwaiti,', 'Mysteries,', 'Middle Eastern Mov...
# 297  ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# 298  ['Social Issue Dramas,', 'Indian,', 'Hindi-Lan...
# 299  ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# 301  ['Mysteries,', 'Indian,', 'Telugu-Language Mov...
#
#                         AboutFull  Age
# 482                  ['Exciting']  16+
# 491                  ['Exciting']  16+
# 502                  ['Exciting']  16+
# 6                             NaN  13+
# 20   ['Suspenseful,', 'Exciting']  18+
# ..                            ...  ...
# 296  ['Mind-Bending,', 'Ominous']  13+
# 297        ['Scary,', 'Romantic']  16+
# 298         ['Cerebral,', 'Dark']  16+
# 299    ['Emotional,', 'Exciting']  13+
# 301                  ['Romantic']  13+
#
# [1842 rows x 10 columns]

# %%
#delete the duplicated movies.
df.drop_duplicates(subset=['Title','Year'], keep='first', inplace=True)

# %%
df.describe(include='all')
# Out:
#        Title         Year Duration    MostLiked  \
# count   3297  3297.000000     3297  3297.000000
# unique  3278          NaN      218          NaN
# top      Nan          NaN   1h 37m          NaN
# freq       7          NaN       78          NaN
# mean     NaN  2015.904762      NaN     0.018805
# std      NaN     7.397563      NaN     0.135856
# min      NaN  1945.000000      NaN     0.000000
# 25%      NaN  2015.000000      NaN     0.000000
# 50%      NaN  2018.000000      NaN     0.000000
# 75%      NaN  2020.000000      NaN     0.000000
# max      NaN  2022.000000      NaN     1.000000
#
#                                               Description Director  \
# count                                                3270     3083
# unique                                               3229     2244
# top     This thriller traces a now-infamous fugitive's...      Nan
# freq                                                    5       41
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#                                                  FullCast  \
# count                                                3057
# unique                                               2872
# top     ['Vatsal Dubey,', 'Julie Tejwani,', 'Rupa Bhim...
# freq                                                   13
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                GenreFull     AboutFull   Age
# count                               3271          2862  3297
# unique                              1569           486     5
# top     ['Stand-Up Comedy,', 'Comedies']  ['Exciting']   16+
# freq                                 222           211  1480
# mean                                 NaN           NaN   NaN
# std                                  NaN           NaN   NaN
# min                                  NaN           NaN   NaN
# 25%                                  NaN           NaN   NaN
# 50%                                  NaN           NaN   NaN
# 75%                                  NaN           NaN   NaN
# max                                  NaN           NaN   NaN

# %%
#change the Titles to index
df = df.set_index('Title')

# %%
#remove '+', 'ALL' from Age column 
df['Age'] = df['Age'].str.replace('+','')
df['Age'] = df['Age'].str.replace('ALL', '0')

# %%
#check the types
df.Age.unique()
# Out:
# array(['13', '16', '18', '7', '0'], dtype=object)

# %%
#cheage the Age from string to int
df['Age'] = df['Age'].apply(int)

# %%
df.Age.unique()
# Out:
# array([13, 16, 18,  7,  0], dtype=int64)

# %%
#how many NULL for each category
df.isnull().sum()
# Out:
# Year             0
# Duration         0
# MostLiked        0
# Description     27
# Director       214
# FullCast       240
# GenreFull       26
# AboutFull      435
# Age              0
# dtype: int64

# %%
df = df.dropna(subset=['FullCast'])

# %%
df = df.dropna(subset=['AboutFull'])

# %%
df = df.dropna(subset=['GenreFull'])

# %%
df = df.dropna(subset=['Director'])

# %%
#how many NULL for each category
df.isnull().sum()
# Out:
# Year           0
# Duration       0
# MostLiked      0
# Description    0
# Director       0
# FullCast       0
# GenreFull      0
# AboutFull      0
# Age            0
# dtype: int64

# %%
#check the paramers frequency in Age
df.Age.describe()
# Out:
# count    2651.000000
# mean       13.186345
# std         3.915231
# min         0.000000
# 25%        13.000000
# 50%        13.000000
# 75%        16.000000
# max        18.000000
# Name: Age, dtype: float64

# %%
#what is the amount of each parameter
df.Age.value_counts()
# Out:
# 16    1168
# 13    1005
# 7      324
# 0      102
# 18      52
# Name: Age, dtype: int64

# %%
#replace the cells that have a NULL value with the most common value
df.Age = df.Age.fillna(df.Age.mode()[0])

# %%
df.Director = df.Director.fillna(df.Director.mode()[0])

# %%
df.Duration.describe()
# Out:
# count       2651
# unique       191
# top       1h 37m
# freq          68
# Name: Duration, dtype: object

# %%
df['Duration'].unique()
# Out:
# array(['1h 46m', '2h 49m', '1h 58m', '1h 45m', '2h 25m', '2h 3m',
#        '1h 49m', '1h 29m', '1h 38m', '1h 59m', '2h 2m', '1h 47m',
#        '1h 57m', '2h 1m', '1h 56m', '2h 38m', '1h 52m', '2h 19m',
#        '2h 16m', '1h 53m', '2h', '2h 7m', '2h 24m', '2h 4m', '2h 12m',
#        '1h 44m', '1h 31m', '2h 15m', '2h 9m', '2h 8m', '1h 43m', '1h 37m',
#        '1h 28m', '2h 13m', '2h 26m', '2h 5m', '1h 30m', '1h 54m',
#        '2h 17m', '1h 48m', '1h 42m', '2h 32m', '2h 21m', '1h 35m',
#        '1h 41m', '1h 51m', '1h 50m', '2h 36m', '2h 11m', '1h 40m',
#        '2h 18m', '2h 22m', '2h 35m', '2h 28m', '1h 34m', '1h 27m',
#        '2h 50m', '3h 7m', '1h 39m', '1h 32m', '2h 23m', '1h 55m',
#        '1h 36m', '1h 26m', '2h 20m', '1h 22m', '2h 44m', '3h 5m',
#        '1h 21m', '2h 29m', '2h 10m', '2h 46m', '1h 23m', '1h 33m',
#        '1h 20m', '2h 39m', '2h 48m', '19m', '2h 14m', '1h 14m', '1h 25m',
#        '2h 42m', '2h 51m', '2h 40m', '2h 27m', '58m', '2h 41m', '2h 6m',
#        '3h 14m', '1h 9m', '3h 33m', '2h 34m', '1h 13m', '2h 33m',
#        '2h 30m', '3h', '2h 43m', '2h 57m', '3h 1m', '3h 23m', '3h 31m',
#        '3h 4m', '3h 2m', '1h 15m', '1h 12m', '53m', '45m', '1h 24m',
#        '25m', '1h 10m', '24m', '1h 4m', '1 Episode', '1h 2m', '47m',
#        '31m', '33m', '22m', '46m', '20m', '26m', '37m', '1h 3m', '1h 5m',
#        '9m', '50m', '57m', '28m', '1h 11m', '27m', '1h 1m', '30m', '35m',
#        '44m', '1h', '42m', '29m', '15m', '23m', '21m', '39m', '32m',
#        '1h 7m', '1h 8m', '1h 6m', '12m', '1h 19m', '1h 18m', '1h 17m',
#        '3h 13m', '49m', '59m', '3h 6m', '55m', '36m', '56m', '51m',
#        '2h 53m', '1h 16m', '54m', '2h 37m', '13m', '2h 54m', '2h 31m',
#        '3h 8m', '2h 59m', '3h 29m', '17m', '14m', '52m', '34m', '16m',
#        '11m', '6m', '40m', '2h 45m', '2h 56m', '3h 11m', '3h 43m',
#        '3h 22m', '2h 55m', '2 Episodes', '3 Seasons', '13 Collections',
#        '2 Seasons', '6 Episodes', '4 Episodes', '3 Episodes', '2 Parts',
#        'Limited Series', '48m'], dtype=object)

# %%
df['Duration'] = df['Duration'].str.replace('h', ' ')
df['Duration'] = df['Duration'].str.replace('m', '')

# %%
#Deleting exceptional data in Duration

# %%
df= df[df["Duration"].str.contains("Seasons") == False]

# %%
df= df[df["Duration"].str.contains("Episode") == False]

# %%
df= df[df["Duration"].str.contains("Season") == False]

# %%
df= df[df["Duration"].str.contains("Episodes") == False]

# %%
df= df[df["Duration"].str.contains("Collections") == False]

# %%
df= df[df["Duration"].str.contains("Volumes") == False]

# %%
df= df[df["Duration"].str.contains("Parts") == False]

# %%
df= df[df["Duration"].str.contains("Volues") == False]

# %%
df= df[df["Duration"].str.contains("Liited Series") == False]

# %%
df['Duration'].unique()
# Out:
# array(['1  46', '2  49', '1  58', '1  45', '2  25', '2  3', '1  49',
#        '1  29', '1  38', '1  59', '2  2', '1  47', '1  57', '2  1',
#        '1  56', '2  38', '1  52', '2  19', '2  16', '1  53', '2 ', '2  7',
#        '2  24', '2  4', '2  12', '1  44', '1  31', '2  15', '2  9',
#        '2  8', '1  43', '1  37', '1  28', '2  13', '2  26', '2  5',
#        '1  30', '1  54', '2  17', '1  48', '1  42', '2  32', '2  21',
#        '1  35', '1  41', '1  51', '1  50', '2  36', '2  11', '1  40',
#        '2  18', '2  22', '2  35', '2  28', '1  34', '1  27', '2  50',
#        '3  7', '1  39', '1  32', '2  23', '1  55', '1  36', '1  26',
#        '2  20', '1  22', '2  44', '3  5', '1  21', '2  29', '2  10',
#        '2  46', '1  23', '1  33', '1  20', '2  39', '2  48', '19',
#        '2  14', '1  14', '1  25', '2  42', '2  51', '2  40', '2  27',
#        '58', '2  41', '2  6', '3  14', '1  9', '3  33', '2  34', '1  13',
#        '2  33', '2  30', '3 ', '2  43', '2  57', '3  1', '3  23', '3  31',
#        '3  4', '3  2', '1  15', '1  12', '53', '45', '1  24', '25',
#        '1  10', '24', '1  4', '1  2', '47', '31', '33', '22', '46', '20',
#        '26', '37', '1  3', '1  5', '9', '50', '57', '28', '1  11', '27',
#        '1  1', '30', '35', '44', '1 ', '42', '29', '15', '23', '21', '39',
#        '32', '1  7', '1  8', '1  6', '12', '1  19', '1  18', '1  17',
#        '3  13', '49', '59', '3  6', '55', '36', '56', '51', '2  53',
#        '1  16', '54', '2  37', '13', '2  54', '2  31', '3  8', '2  59',
#        '3  29', '17', '14', '52', '34', '16', '11', '6', '40', '2  45',
#        '2  56', '3  11', '3  43', '3  22', '2  55', '48'], dtype=object)

# %%
j=0
for i in df['Duration']:
    if(len(i) == 2 or len(i) == 1):
        df['Duration'][j] = i
    else:
        splintDur = i.split(' ')
    if(len(splintDur) == 3):
        int1 = splintDur[0]
        int2 = splintDur[2]
        int1 = int(int1)
        int2 = int(int2)
        amount = int1 * 60 + int2
        df['Duration'][j] = amount
        j+=1

# %%
df.tail(50)
# Out:
#                                             Year Duration  MostLiked  \
# Title
# Fever Dream                               2021.0       93        0.0
# Dhamaka                                   2021.0      104        0.0
# A Sort of Family                          2017.0       96        0.0
# Unsane                                    2018.0       97        0.0
# Sin City                                  2019.0      101        0.0
# Photocopier                               2022.0      130        0.0
# Anatomy                                   2000.0       99        0.0
# Ammar                                     2020.0       83        0.0
# The Intruders                             2015.0       92        0.0
# Mercy                                     2016.0       87        0.0
# Prime Time                                2021.0       92        0.0
# Unbridled                                 2018.0      100        0.0
# Raajneeti                                 2010.0      161        0.0
# Ghost Lab                                 2021.0      117        0.0
# Romeo Akbar Walter                        2019.0      140        0.0
# THE WOLF HOUR                             2019.0       99        0.0
# Time Share                                2018.0       96        0.0
# The Most Assassinated Woman in the World  2018.0      102        0.0
# Dead Kids                                 2019.0       94        0.0
# White Noise                               2017.0       92        0.0
# Karthik Calling Karthik                   2010.0      134        0.0
# The CEO                                   2016.0      108        0.0
# A Place in the Stars                      2014.0      109        0.0
# Game Over (Hindi Version)                 2019.0       97        0.0
# Voiceless                                 2020.0      111        0.0
# Gurgaon                                   2017.0      106        0.0
# The Guardian                              2021.0      127        0.0
# Taxi No. 9211                             2006.0      115        0.0
# Irul                                      2021.0       91        0.0
# Wazir                                     2016.0       97        0.0
# Thambi                                    2019.0      147        0.0
# Game Over (Tamil Version)                 2019.0       97        0.0
# Nan                                       1998.0      155        0.0
# Game Over (Telugu Version)                2019.0       97        0.0
# Bypass Road                               2019.0      135        0.0
# Sylvia                                    2018.0      104        0.0
# Boomika                                   2021.0      122        0.0
# Govinda Govinda                           2021.0      137        0.0
# Kucch To Hai                              2003.0      135        0.0
# Blue, Painful, Fragile                    2020.0      118        0.0
# The Royal Bengal Tiger                    2014.0      103        0.0
# My Birthday Song                          2018.0       91        0.0
# Puriyatha Puthir                          2017.0      119        0.0
# Ghanchakkar                               2013.0      128        0.0
# Boomika (Malayalam)                       2021.0      122        0.0
# Aaviri                                    2019.0      109        0.0
# Until Midnight                            2019.0       77        0.0
# Kolaiyuthir Kaalam                        2019.0      107        0.0
# Boomika (Hindi)                           2021.0      122        0.0
# Boomika (Telugu)                          2021.0      122        0.0
#
#                                                                                 Description  \
# Title
# Fever Dream                               The charged relationship between two young mom...
# Dhamaka                                   When a cynical ex-TV news anchor gets an alarm...
# A Sort of Family                          An Argentine doctor faces legal and ethical ch...
# Unsane                                    After moving away from home to escape a stalke...
# Sin City                                  A busy couple tries to give their love life a ...
# Photocopier                               When photos of her at a party cause her to los...
# Anatomy                                   A young medical student uncovers a horrifying ...
# Ammar                                     When a family moves into an old castle, excite...
# The Intruders                             After her mother's death, a troubled girl and ...
# Mercy                                     Two brothers clash with their half-siblings wh...
# Prime Time                                On New Year’s Eve 1999, an armed man enters a ...
# Unbridled                                 Desperate to keep her husband’s secret, a devo...
# Raajneeti                                 When the American-educated scion of a powerful...
# Ghost Lab                                 After witnessing a haunting in their hospital,...
# Romeo Akbar Walter                        In 1971, a fallen army major’s son is tapped b...
# THE WOLF HOUR                             In 1977 New York, an agoraphobic author strugg...
# Time Share                                Husband and father Pedro becomes increasingly ...
# The Most Assassinated Woman in the World  In 1930s Paris, an actress famous for her gory...
# Dead Kids                                 A socially awkward teen bonds with a group of ...
# White Noise                               In search of an adventure, a bored billionaire...
# Karthik Calling Karthik                   Unlucky in love and bullied at work, an office...
# The CEO                                   A group of executives heads to a telecommunica...
# A Place in the Stars                      A young lawyer who has information about count...
# Game Over (Hindi Version)                 As a series of murders hit close to home, a vi...
# Voiceless                                 A bright and promising young girl gets abducte...
# Gurgaon                                   When the daughter of a wealthy family returns ...
# The Guardian                              A tragedy surrounding a pop star propels her b...
# Taxi No. 9211                             When an arrogant scion hails his taxi, a cabbi...
# Irul                                      When a car breakdown forces a couple to seek s...
# Wazir                                     Helping an amputee grandmaster settle the scor...
# Thambi                                    As a tip leads a local politician to his long-...
# Game Over (Tamil Version)                 As a series of murders hit close to home, a vi...
# Nan                                       On the run from Indian police, a mysterious ma...
# Game Over (Telugu Version)                As a series of murders hit close to home, a vi...
# Bypass Road                               On the night his ex-lover mysteriously dies, a...
# Sylvia                                    When a man outgrows a childhood friendship and...
# Boomika                                   Paranormal activity at a lush, abandoned prope...
# Govinda Govinda                           Three college slackers fake a friend's kidnapp...
# Kucch To Hai                              A student tries to steal a test from a teacher...
# Blue, Painful, Fragile                    Kaede and Hisano form a club to change the wor...
# The Royal Bengal Tiger                    Knocked down by life one too many times, a mee...
# My Birthday Song                          After a wild night of impulse and infidelity, ...
# Puriyatha Puthir                          An aspiring music director begins to receive v...
# Ghanchakkar                               Former con artist Sanju surrounds himself with...
# Boomika (Malayalam)                       Paranormal activity at a lush, abandoned prope...
# Aaviri                                    After losing their first child in an accident,...
# Until Midnight                            After returning home from a work trip, a newly...
# Kolaiyuthir Kaalam                        The speech-and-hearing-impaired heiress of a p...
# Boomika (Hindi)                           Paranormal activity at a lush, abandoned prope...
# Boomika (Telugu)                          Paranormal activity at a lush, abandoned prope...
#
#                                                                                    Director  \
# Title
# Fever Dream                                                               ['Claudia Llosa']
# Dhamaka                                                                    ['Ram Madhvani']
# A Sort of Family                                                           ['Diego Lerman']
# Unsane                                                                ['Steven Soderbergh']
# Sin City                                                                  ['Pascal Amanfo']
# Photocopier                                                            ['Wregas Bhanuteja']
# Anatomy                                                              ['Stephan Ruzowitzky']
# Ammar                                                                     ['Mahmoud Kamel']
# The Intruders                                                               ['Adam Massey']
# Mercy                                                                    ['Chris Sparling']
# Prime Time                                                                 ['Jakub Piątek']
# Unbridled                                                                  ['Jota Linares']
# Raajneeti                                                                   ['Prakash Jha']
# Ghost Lab                                                           ['Paween Purijitpanya']
# Romeo Akbar Walter                                                        ['Robbie Grewal']
# THE WOLF HOUR                                                    ['Alistair Banks Griffin']
# Time Share                                                            ['Sebastián Hofmann']
# The Most Assassinated Woman in the World                                 ['Franck Ribière']
# Dead Kids                                                                   ['Mikhail Red']
# White Noise                                                               ['Salim el Turk']
# Karthik Calling Karthik                                                   ['Vijay Lalwani']
# The CEO                                                                  ['Kunle Afolayan']
# A Place in the Stars                                                        ['Steve Gukas']
# Game Over (Hindi Version)                                              ['Ashwin Saravanan']
# Voiceless                                                              ['Robert O. Peters']
# Gurgaon                                                                   ['Shanker Raman']
# The Guardian                                                                  ['Victor Vu']
# Taxi No. 9211                                                             ['Milan Luthria']
# Irul                                                               ['Naseef Yusuf Izuddin']
# Wazir                                                                     ['Bejoy Nambiar']
# Thambi                                                                    ['Jeethu Joseph']
# Game Over (Tamil Version)                                              ['Ashwin Saravanan']
# Nan                                       ['Abbas Alibhai Burmawalla,', 'Mastan Alibhai ...
# Game Over (Telugu Version)                                             ['Ashwin Saravanan']
# Bypass Road                                                          ['Naman Nitin Mukesh']
# Sylvia                                                                    ['Daniel Oriahi']
# Boomika                                                             ['Rathindran R Prasad']
# Govinda Govinda                                                                  ['Thilak']
# Kucch To Hai                                              ['Anil V. Kumar,', 'Anurag Basu']
# Blue, Painful, Fragile                                                ['Shunsuke Kariyama']
# The Royal Bengal Tiger                                                   ['Rajesh Ganguly']
# My Birthday Song                                                             ['Samir Soni']
# Puriyatha Puthir                                                        ['Ranjit Jeyakodi']
# Ghanchakkar                                                             ['Raj Kumar Gupta']
# Boomika (Malayalam)                                                 ['Rathindran R Prasad']
# Aaviri                                                                        ['Ravi Babu']
# Until Midnight                                                            ['Tariq Alkazim']
# Kolaiyuthir Kaalam                                                        ['Chakri Toleti']
# Boomika (Hindi)                                                     ['Rathindran R Prasad']
# Boomika (Telugu)                                                    ['Rathindran R Prasad']
#
#                                                                                    FullCast  \
# Title
# Fever Dream                               ['María Valverde,', 'Dolores Fonzi,', 'Germán ...
# Dhamaka                                   ['Kartik Aaryan,', 'Amruta Subhash,', 'Mrunal ...
# A Sort of Family                          ['Bárbara Lennie,', 'Daniel Aráoz,', 'Claudio ...
# Unsane                                    ['Claire Foy,', 'Joshua Leonard,', 'Jay Pharoa...
# Sin City                                  ['Yvonne Nelson,', 'Kunle Remi,', 'Adjetey Ana...
# Photocopier                               ['Shenina Cinnamon,', 'Chicco Kurniawan,', 'Je...
# Anatomy                                   ['Franka Potente,', 'Benno Fürmann,', 'Anna Lo...
# Ammar                                     ['Sharif Salamah,', 'Eman Al Assy,', 'Hala El-...
# The Intruders                             ['Miranda Cosgrove,', 'Donal Logue,', 'Austin ...
# Mercy                                     ['James Wolk,', 'Caitlin Fitzgerald,', 'Tom Li...
# Prime Time                                ['Bartosz Bielenia,', 'Magdalena Popławska,', ...
# Unbridled                                 ['Natalia de Molina,', 'Daniel Grao,', 'Natali...
# Raajneeti                                 ['Ajay Devgn,', 'Nana Patekar,', 'Ranbir Kapoo...
# Ghost Lab                                 ['Thanapob Leeratanakachorn,', 'Paris Intarako...
# Romeo Akbar Walter                        ['John Abraham,', 'Jackie Shroff,', 'Mouni Roy...
# THE WOLF HOUR                             ['Naomi Watts,', 'Jennifer Ehle,', 'Emory Cohe...
# Time Share                                ['Luis Gerardo Méndez,', 'Miguel Rodarte,', 'R...
# The Most Assassinated Woman in the World  ['Anna Mouglalis,', 'Niels Schneider,', 'André...
# Dead Kids                                 ['Khalil Ramos,', 'Vance Larena,', 'Kelvin Mir...
# White Noise                               ['Nicolas Mouawad,', 'Zeina Makki,', 'Marcel A...
# Karthik Calling Karthik                   ['Farhan Akhtar,', 'Deepika Padukone,', 'Ram K...
# The CEO                                   ['Wale Ojo,', 'Jimmy Jean-Louis,', 'Hilda Doku...
# A Place in the Stars                      ['Gideon Okeke,', 'Dejumo Lewis,', 'Segun Arin...
# Game Over (Hindi Version)                 ['Taapsee Pannu,', 'Vinodhini,', 'Parvathi T,'...
# Voiceless                                 ['Uzee Usman,', 'Yakubu Mohammed,', 'Asabe Mad...
# Gurgaon                                   ['Akshay Oberoi,', 'Pankaj Tripathi,', 'Ragini...
# The Guardian                              ['Truc Anh,', 'Amee,', 'Salim,', 'Samuel An,',...
# Taxi No. 9211                             ['Nana Patekar,', 'John Abraham,', 'Sameera Re...
# Irul                                      ['Fahadh Faasil,', 'Soubin Shahir,', 'Darshana...
# Wazir                                     ['Amitabh Bachchan,', 'Farhan Akhtar,', 'Aditi...
# Thambi                                    ['Jyothika,', 'Sathyaraj,', 'Karthi,', 'Showka...
# Game Over (Tamil Version)                 ['Taapsee Pannu,', 'Vinodhini,', 'Parvathi T,'...
# Nan                                       ['Bobby Deol,', 'Preity Zinta,', 'Suresh Obero...
# Game Over (Telugu Version)                ['Taapsee Pannu,', 'Vinodhini,', 'Parvathi T,'...
# Bypass Road                               ['Neil Nitin Mukesh,', 'Adah Sharma,', 'Rajit ...
# Sylvia                                    ['Chris Attoh,', 'Zainab Balogun,', 'Ini Dima-...
# Boomika                                   ['Aishwarya Rajesh,', 'Vidhu,', 'Surya Ganapat...
# Govinda Govinda                           ['Roopesh Shetty,', 'Bhavana,', 'Sumanth Shail...
# Kucch To Hai                              ['Tusshar Kapoor,', 'Esha Deol,', 'Natassha,',...
# Blue, Painful, Fragile                    ['Ryo Yoshizawa,', 'Hana Sugisaki,', 'Amane Ok...
# The Royal Bengal Tiger                    ['Jeet,', 'Abir Chatterjee,', 'Priyanka Sarkar...
# My Birthday Song                          ['Sanjay Suri,', 'Nora Fatehi,', 'Zenia Starr,...
# Puriyatha Puthir                          ['Vijay Sethupathi,', 'Gayathrie,', 'Mahima Na...
# Ghanchakkar                               ['Emraan Hashmi,', 'Vidya Balan,', 'Rajesh Sha...
# Boomika (Malayalam)                       ['Aishwarya Rajesh,', 'Vidhu,', 'Surya Ganapat...
# Aaviri                                    ['Ravi Babu,', 'Neha Chauhan,', 'Sri Muktha,',...
# Until Midnight                            ['Ahmad Khamis Ali,', 'Chuka Ekweogwu,', 'Heba...
# Kolaiyuthir Kaalam                        ['Nayanthara,', 'Bhoomika Chawla,', 'Prem Kath...
# Boomika (Hindi)                           ['Aishwarya Rajesh,', 'Vidhu,', 'Surya Ganapat...
# Boomika (Telugu)                          ['Aishwarya Rajesh,', 'Vidhu,', 'Surya Ganapat...
#
#                                                                                   GenreFull  \
# Title
# Fever Dream                               ['Movies Based on Books,', 'Dramas,', 'Thrille...
# Dhamaka                                   ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# A Sort of Family                          ['Argentinian,', 'Social Issue Dramas,', 'Dram...
# Unsane                                                                  ['Thriller Movies']
# Sin City                                  ['Mysteries,', 'African Movies,', 'Thriller Mo...
# Photocopier                               ['Indonesian,', 'Mysteries,', 'Social Issue Dr...
# Anatomy                                    ['German,', 'Thriller Movies,', 'Horror Movies']
# Ammar                                     ['Egyptian,', 'Middle Eastern Movies,', 'Thril...
# The Intruders                                ['Canadian,', 'Mysteries,', 'Thriller Movies']
# Mercy                                                        ['Dramas,', 'Thriller Movies']
# Prime Time                                        ['Polish,', 'Dramas,', 'Thriller Movies']
# Unbridled                                                   ['Spanish,', 'Thriller Movies']
# Raajneeti                                 ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# Ghost Lab                                    ['Thai,', 'Thriller Movies,', 'Horror Movies']
# Romeo Akbar Walter                        ['Spy Movies,', 'Indian,', 'Hindi-Language Mov...
# THE WOLF HOUR                                                           ['Thriller Movies']
# Time Share                                       ['Mexican,', 'Dramas,', 'Thriller Movies']
# The Most Assassinated Woman in the World  ['Period Pieces,', 'French,', 'Dramas,', 'Thri...
# Dead Kids                                 ['Filipino,', 'Teen Movies,', 'Dramas,', 'Thri...
# White Noise                               ['Lebanese,', 'Social Issue Dramas,', 'Middle ...
# Karthik Calling Karthik                   ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# The CEO                                   ['Mysteries,', 'Nollywood,', 'African Movies,'...
# A Place in the Stars                      ['Social Issue Dramas,', 'Nollywood,', 'Africa...
# Game Over (Hindi Version)                 ['Indian,', 'Hindi-Language Movies,', 'Thrille...
# Voiceless                                 ['Nollywood,', 'African Movies,', 'Dramas,', '...
# Gurgaon                                   ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# The Guardian                                  ['Vietnamese,', 'Dramas,', 'Thriller Movies']
# Taxi No. 9211                             ['Social Issue Dramas,', 'Indian,', 'Hindi-Lan...
# Irul                                      ['Indian,', 'Malayalam-Language Movies,', 'Thr...
# Wazir                                     ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# Thambi                                    ['Indian,', 'Tamil-Language Movies,', 'Thrille...
# Game Over (Tamil Version)                 ['Indian,', 'Tamil-Language Movies,', 'Thrille...
# Nan                                       ['Romantic Comedies,', 'Indian,', 'Hindi-Langu...
# Game Over (Telugu Version)                ['Indian,', 'Telugu-Language Movies,', 'Thrill...
# Bypass Road                               ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# Sylvia                                    ['Nollywood,', 'African Movies,', 'Dramas,', '...
# Boomika                                   ['Indian,', 'Tamil-Language Movies,', 'Thrille...
# Govinda Govinda                           ['Indian,', 'Kannada Movies & TV,', 'Comedies,...
# Kucch To Hai                              ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# Blue, Painful, Fragile                    ['Japanese,', 'Teen Movies,', 'Movies Based on...
# The Royal Bengal Tiger                    ['Indian,', 'Bengali-Language Movies,', 'Drama...
# My Birthday Song                          ['Mysteries,', 'Indian,', 'Hindi-Language Movi...
# Puriyatha Puthir                          ['Indian,', 'Tamil-Language Movies,', 'Thrille...
# Ghanchakkar                               ['Indian,', 'Hindi-Language Movies,', 'Bollywo...
# Boomika (Malayalam)                       ['Indian,', 'Malayalam-Language Movies,', 'Thr...
# Aaviri                                    ['Indian,', 'Telugu-Language Movies,', 'Thrill...
# Until Midnight                            ['Emirati,', 'Middle Eastern Movies,', 'Thrill...
# Kolaiyuthir Kaalam                        ['Indian,', 'Tamil-Language Movies,', 'Thrille...
# Boomika (Hindi)                           ['Indian,', 'Hindi-Language Movies,', 'Thrille...
# Boomika (Telugu)                          ['Indian,', 'Telugu-Language Movies,', 'Thrill...
#
#                                                                        AboutFull  \
# Title
# Fever Dream                                                      ['Suspenseful']
# Dhamaka                                                                      Nan
# A Sort of Family                                                 ['Suspenseful']
# Unsane                                                                       Nan
# Sin City                                                              ['Steamy']
# Photocopier                                                      ['Suspenseful']
# Anatomy                                                          ['Suspenseful']
# Ammar                                      ['Ominous,', 'Scary,', 'Suspenseful']
# The Intruders                                             ['Chilling,', 'Scary']
# Mercy                                                   ['Dark,', 'Suspenseful']
# Prime Time                                                                   Nan
# Unbridled                                                        ['Suspenseful']
# Raajneeti                                                               ['Dark']
# Ghost Lab                                        ['Chilling,', 'Scary,', 'Dark']
# Romeo Akbar Walter                                        ['Dark,', 'Emotional']
# THE WOLF HOUR                                                    ['Suspenseful']
# Time Share                                                          ['Cerebral']
# The Most Assassinated Woman in the World                                ['Dark']
# Dead Kids                                               ['Dark,', 'Suspenseful']
# White Noise                                                                  Nan
# Karthik Calling Karthik                                                      Nan
# The CEO                                                            ['Emotional']
# A Place in the Stars                                  ['Gritty,', 'Suspenseful']
# Game Over (Hindi Version)                                  ['Violent,', 'Scary']
# Voiceless                                   ['Violent,', 'Gritty,', 'Emotional']
# Gurgaon                                                                 ['Dark']
# The Guardian                              ['Chilling,', 'Scary,', 'Suspenseful']
# Taxi No. 9211                                                        ['Offbeat']
# Irul                                                      ['Chilling,', 'Scary']
# Wazir                                                 ['Emotional,', 'Exciting']
# Thambi                                             ['Suspenseful,', 'Emotional']
# Game Over (Tamil Version)                                  ['Violent,', 'Scary']
# Nan                                                   ['Emotional,', 'Romantic']
# Game Over (Telugu Version)                                 ['Violent,', 'Scary']
# Bypass Road                                                             ['Dark']
# Sylvia                                                           ['Suspenseful']
# Boomika                                                ['Scary,', 'Suspenseful']
# Govinda Govinda                                        ['Quirky,', 'Irreverent']
# Kucch To Hai                                                     ['Suspenseful']
# Blue, Painful, Fragile                           ['Sentimental,', 'Suspenseful']
# The Royal Bengal Tiger                                  ['Dark,', 'Suspenseful']
# My Birthday Song                                           ['Cerebral,', 'Dark']
# Puriyatha Puthir                                                 ['Suspenseful']
# Ghanchakkar                                           ['Offbeat,', 'Irreverent']
# Boomika (Malayalam)                                    ['Scary,', 'Suspenseful']
# Aaviri                                     ['Ominous,', 'Scary,', 'Suspenseful']
# Until Midnight                                                   ['Suspenseful']
# Kolaiyuthir Kaalam                                               ['Suspenseful']
# Boomika (Hindi)                                        ['Scary,', 'Suspenseful']
# Boomika (Telugu)                                       ['Scary,', 'Suspenseful']
#
#                                           Age
# Title
# Fever Dream                                13
# Dhamaka                                    13
# A Sort of Family                           13
# Unsane                                     16
# Sin City                                   16
# Photocopier                                16
# Anatomy                                    16
# Ammar                                      16
# The Intruders                              16
# Mercy                                      16
# Prime Time                                 16
# Unbridled                                  16
# Raajneeti                                  13
# Ghost Lab                                  16
# Romeo Akbar Walter                         13
# THE WOLF HOUR                              16
# Time Share                                 13
# The Most Assassinated Woman in the World   16
# Dead Kids                                  16
# White Noise                                13
# Karthik Calling Karthik                    13
# The CEO                                    13
# A Place in the Stars                       13
# Game Over (Hindi Version)                  16
# Voiceless                                  16
# Gurgaon                                    13
# The Guardian                               16
# Taxi No. 9211                              13
# Irul                                       16
# Wazir                                      16
# Thambi                                     16
# Game Over (Tamil Version)                  16
# Nan                                        16
# Game Over (Telugu Version)                 16
# Bypass Road                                13
# Sylvia                                     13
# Boomika                                    13
# Govinda Govinda                            13
# Kucch To Hai                               13
# Blue, Painful, Fragile                     13
# The Royal Bengal Tiger                     16
# My Birthday Song                           13
# Puriyatha Puthir                           16
# Ghanchakkar                                13
# Boomika (Malayalam)                        13
# Aaviri                                     13
# Until Midnight                             13
# Kolaiyuthir Kaalam                         16
# Boomika (Hindi)                            13
# Boomika (Telugu)                           13

# %%
#cheage the Duration from string to int
df['Duration'] = df['Duration'].apply(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2630 entries, The Adam Project to Boomika (Telugu)
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         2630 non-null   float64
#  1   Duration     2630 non-null   int64
#  2   MostLiked    2630 non-null   float64
#  3   Description  2630 non-null   object
#  4   Director     2630 non-null   object
#  5   FullCast     2630 non-null   object
#  6   GenreFull    2630 non-null   object
#  7   AboutFull    2630 non-null   object
#  8   Age          2630 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 270.0+ KB

# %%
#Save a new CSV file after data cleaning
df.to_csv("DF_After_DataCleaning.csv")
